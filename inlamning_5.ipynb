# %% [markdown]
# # Assignment 5: Modelling Earth's climate: the ice albedo feedback

# %% [markdown]
# ## Introduction
#
# Earth's surface temperature is set by its energy balance: the incoming solar radiation absorbed by the planet must, on average, equal the outgoing radiation it emits back to space. One important part of this balance is Earth's **albedo** — the fraction of incoming sunlight reflected back to space — and how strongly it depends on the extent of ice and snow. Since temperature controls how much ice and snow exist, there is a **positive feedback loop** between surface temperature and albedo: a colder planet has more ice, which reflects more sunlight, which cools the planet further (and vice versa for a warmer planet).
#
# This feedback can create **tipping points**: thresholds where the system shifts abruptly and, on human timescales, irreversibly, between two extreme states. The two extreme states are a planet with no polar ice at all, and a planet that is entirely ice-covered ("Snowball Earth").
#
# In this assignment we will create a simple energy balance model based on what you have seen in the previous course "Jorden som system". You will write your own **zero-dimensional (0-D) energy balance model**, in which albedo depends on surface temperature. You are going to explore the ice-albedo feedback and its influence on the system's path to equilibrium. Your developed model will further be used to study how the starting conditions of your climate system (initial temperature, greenhouse gas concentration, land cover, solar constant) affect the modelled system. You will explore the Earth's tipping points related to the ice-albedo feedback mechanism: when could Earth become a Snowball Earth?

# %% [markdown]
# ## Task A: The Realization of your model in Python
#
# You can develop your model here in this notebook directly, or as a separate script. Either way, developing your model starts with the equations describing Earth's energy balance:
# $$
# \frac{1}{4} S (1 - A) = \sigma \cdot T^4 \cdot (1 - 0.5 \epsilon).
# $$
#
#
# To be able to simulate the ice-albedo feedback, you need to include a relationship between albedo and temperature:
# $$
# A(T) =
# \begin{cases}
# A_i & T \le T_i \\
# A_0 + (A_i - A_0)\dfrac{(T - T_0)^2}{(T_i - T_0)^2} & T_i < T < T_0 \\
# A_0 & T \ge T_0
# \end{cases}
# $$
#
# with $A_i = 0.7$, $A_0 = 0.289$, $T_i = 260\ \text{K}$, $T_0 = 293\ \text{K}$ ($T_i$ is the threshold below which the planet is entirely ice-covered, and $T_0$ the threshold above which it is ice-free).
# This model represents Earth as a single point with one temperature $T$ and one albedo $A$ (0D).
#
# <div class="alert alert-warning">
# <b>Info:</b>
#     This is a linear system of equations which you should solve
#     <details><summary>Hint:</summary> To solve this linear system of equations different approaches can be used - to give some hint on the approach we recommend here: you have used similar approaches before to calculate the square root and the val-krill problem with Dag.</details>
# </div>
#
# Starting from today's approximate values:
# - $T = 288\text{K}$
# - $\varepsilon = 0.78$ (emissivity)
# -  $S = 1360\ \text{W/m}^2$ (solar constant)
#
# let your model run until it reaches equilibrium and visualize the results.

# %%
# Write your code here, add more cells as needed.

# %% [markdown]
# ## Task B: Hysteresis
#
# A system shows **hysteresis** when its current state depends not only on the external conditions acting on it right now, but also on the *path* it took to get there — on its history. Hysteresis is closely linked to **bistability**: if a system has two different stable equilibria for the exact same external conditions, the state it ends up in depends on where it started or on which direction a parameter was changed from. Parts of the real climate system (such as ocean circulation patterns or ice sheets) can show this behaviour: pushing a system past a tipping point in one direction does not guarantee that reversing the push by the same amount will undo the change. Note that hysteresis is a property of the *equilibrium* behaviour of a system, not of how you compute it — if you ever find different answers depending on how you searched for the equilibrium, that is a symptom of hysteresis in the underlying system, not a bug in your method. Not every system with a sharp, tipping-point-like transition necessarily shows hysteresis, and not every system that changes gradually is free of it. The two properties are related but not identical.
#
# In this task, you should investigate whether the climate model you have developed in this assignment shows hysteresis. Is there evidence that, for some fixed set of parameters, the model can settle into more than one stable equilibrium temperature? Or does it always reach the same equilibrium regardless of how you approach it?
# Think about what “history” could even mean for a model like this one, what kind of numerical experiment would let you detect (or rule out) hysteresis, and what evidence would actually convince you either way. You are free to reuse, combine, or write new code as needed.
#
# Present your experiment, your evidence, and your conclusion clearly enough that someone else could follow your reasoning and reproduce your result. If you find hysteresis, characterize it (e.g. over what range of which parameter does it occur, and how large is the effect). If you conclude the model does not show hysteresis, explain what you tested and why you find that convincing rather than merely an absence of evidence.
#
# What does your result physically mean?

# %%
# Write your code here, add more cells as needed.

# %% [markdown]
# ## Task C: Analyse the climate system and its behaviour in your model (Snowball Earth tipping point)
#
# Your model can further be used to study how the starting conditions, i.e. assumptions of the climate system, affect how the system is modelled. Analyse how the system's equilibrium changes, i.e. the tipping points, and how this depends on the variables in your model.
#
# <div class="alert alert-info">
# <b>Info: </b>You should spend some time thinking about what an appropriate initial temperature is before you start testing the different starting conditions listed below. Is it enough with one?
# </div>
#
# ### 1. The greenhouse effect
#
# Vary the emissivity $\varepsilon$ over a suitable range and record the equilibrium temperature for each value.
# <div class="alert alert-warning">
#     <details>
#         <summary><b>Hint:</b></summary>
# Look at the formula to get an idea what a suitable range might be.
#     </details>
# </div>
#
# How does the equilibrium temperature depend on $\varepsilon$? At what value(s) of $\varepsilon$ does the system tip into a different state (ice-free or entirely ice-covered)? Relate this to the real greenhouse effect: is increasing or decreasing $\varepsilon$ analogous to more greenhouse gases in the atmosphere?

# %%
# Write your code here, add more cells as needed.

# %% [markdown]
# ### 2. The solar constant
#
# Vary the solar constant $S_0$ over a suitable range and record the equilibrium temperature for each value. Varying the solar constant would represent, for example, the Milankovich cycle or the solar cycle. You can check the literature to find representative values. At which values would your simulated Earth system end up in an ice-free or Snowball Earth state?

# %%
# Write your code here, add more cells as needed.

# %% [markdown]
# ### 3. Land cover
#
# The albedo parameters $A_i$ and $A_0$ implicitly represent today's mix of ocean, land, ice, and vegetation. Investigate how the equilibrium changes if you vary $A_0$ (representing, for example, more desert, less forest, or an ocean-only planet with no land at all). Assume the atmosphere's radiative properties ($\varepsilon$) stay the same. Where does the equilibrium temperature shift to?
# How large a change in $A_0$ is needed to push the system into a Snowball Earth state?

# %%
# Write your code here, add more cells as needed.
