# %% [markdown]
# # Assignment 5: Modelling the Earth's climate

# %% [markdown]
# ## Introduction
#
# Earth's surface temperature is set by its energy balance: the incoming solar radiation absorbed by the planet must, on average, equal the outgoing radiation it emits back to space. One important part of this balance is Earth's **albedo** — the fraction of incoming sunlight reflected back to space — and how strongly it depends on the extent of ice and snow. Since temperature controls how much ice and snow exist, there is a **positive feedback loop** between surface temperature and albedo: a colder planet has more ice, which reflects more sunlight, which cools the planet further (and vice versa for a warmer planet).
#
# This feedback can create **tipping points**: thresholds where the system shifts abruptly and, on human timescales, irreversibly, between two extreme states. The two extreme states are a planet with no polar ice at all, and a planet that is entirely ice-covered ("Snowball Earth").
#
# In this assignment we will build upon a simple energy balance model as you have seen in the previous course "Jorden som system" (see more details below). You will write your own simple **zero-dimensional (0-D) energy balance model**, in which albedo depends on surface temperature. You are going to explore the ice-albedo feedback and its influence on the system's path to equilibrium. Your developed model will further be used to study how the starting conditions of your climate system (greenhouse gas concentration, land cover, solar constant) affect the modelled system. You will explore the Earth's tipping points related to this feedback mechanism: when could Earth become a Snowball Earth?

# %% [markdown]
# ## The Realization of your model in Python
#
# To develop your model you can start with the simple EBM we used in the previous course "Jorden som system":
# $$
# T_s = \left( \frac{S(1-A)}{4\sigma} \right)^{1/4}
# $$
#
# This model represents Earth as a single point with one temperature $T$ and one albedo $A$. To be able to simulate the ice-albedo feedback implement a relationship between albedo and temperature:
# $$
# A(T) =
# \begin{cases}
# A_i & T \le T_i \\
# A_0 + (A_i - A_0)\dfrac{(T - T_0)^2}{(T_i - T_0)^2} & T_i < T < T_0 \\
# A_0 & T \ge T_0
# \end{cases}
# $$
#
# with $A_i = 0.7$, $A_0 = 0.289$, $T_i = 260\ \text{K}$, $T_0 = 293\ \text{K}$ ($T_i$ is the threshold below which the planet is entirely ice-covered, and $T_0$ the threshold above which it is ice-free).
#
# Starting from today's approximate values ($T = 288\ \text{K}$, emissivity $\varepsilon = 0.78$, solar constant $S = 1360\ \text{W/m}^2$), let your model run until it reaches equilibrium and let it visualize the result (you can double check your numbers in the control question in the quiz or give some controll values here?).
#
#
# ### Model implementation
#
# Implement your model in the cells below.
# Add as many new cells as you need.
#
# Alternatively, write you model in a separate Python-file and import it below.

# %%
# Write your code here, add more cells as needed.

# %% [markdown]
# ## Questions

# %% [markdown]
# ### Part 1

# %% [markdown]
# #### Question 1

# %% [markdown]
# #### Question 2

# %% [markdown]
# ### Part 2

# %% [markdown]
# #### Question 3
